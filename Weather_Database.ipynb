# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | xining
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | san rafael del sur
# Processing Record 7 of Set 1 | harrisonville
# Processing Record 8 of Set 1 | tigil
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | richards bay
# Processing Record 12 of Set 1 | adrar
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | north bend
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | saint-augustin
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | biguacu
# Processing Record 24 of Set 1 | sao lourenco
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | ouadda
# Processing Record 29 of Set 1 | aksu
# Processing Record 30 of Set 1 | dharchula
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | boysun
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | wanning
# Processing Record 40 of Set 1 | biak
# Processing Record 41 of Set 1 | lazaro cardenas
# Processing Record 42 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 1 | lagos
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | mount gambier
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | hobyo
# Processing Record 48 of Set 1 | yar-sale
# Processing Record 49 of Set 1 | abu dhabi
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | chimbote
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | pacifica
# Processing Record 4 of Set 2 | suntar
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | maneadero
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | misratah
# Processing Record 9 of Set 2 | teknaf
# Processing Record 10 of Set 2 | cherskiy
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | norman wells
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | arenal
# Processing Record 17 of Set 2 | touros
# Processing Record 18 of Set 2 | kawalu
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | inirida
# Processing Record 22 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 2 | freeport
# Processing Record 24 of Set 2 | muros
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 2 | srednekolymsk
# Processing Record 28 of Set 2 | kavaratti
# Processing Record 29 of Set 2 | oktyabrskiy
# Processing Record 30 of Set 2 | mweka
# Processing Record 31 of Set 2 | palmerston
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | vestmannaeyjar
# Processing Record 34 of Set 2 | ginir
# Processing Record 35 of Set 2 | ambanja
# Processing Record 36 of Set 2 | ponta delgada
# Processing Record 37 of Set 2 | vila velha
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | lubango
# Processing Record 44 of Set 2 | sinnamary
# Processing Record 45 of Set 2 | bambanglipuro
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | tahta
# Processing Record 50 of Set 2 | ampanihy
# Processing Record 1 of Set 3 | hammerfest
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | langsa
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | olden
# Processing Record 6 of Set 3 | pacific grove
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | akcakoca
# Processing Record 10 of Set 3 | pierre
# Processing Record 11 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 12 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 3 | shingu
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | ellenabad
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | coquimbo
# Processing Record 19 of Set 3 | doka
# Processing Record 20 of Set 3 | necochea
# Processing Record 21 of Set 3 | laguna
# Processing Record 22 of Set 3 | geraldton
# Processing Record 23 of Set 3 | narsaq
# Processing Record 24 of Set 3 | waingapu
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | mikhaylovsk
# Processing Record 28 of Set 3 | loikaw
# Processing Record 29 of Set 3 | oxford
# Processing Record 30 of Set 3 | severobaykalsk
# Processing Record 31 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 3 | oda
# Processing Record 33 of Set 3 | gremyachye
# City not found. Skipping...
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | brigantine
# Processing Record 37 of Set 3 | saldanha
# Processing Record 38 of Set 3 | kantunilkin
# Processing Record 39 of Set 3 | son tay
# Processing Record 40 of Set 3 | tandalti
# Processing Record 41 of Set 3 | haines junction
# Processing Record 42 of Set 3 | olinda
# Processing Record 43 of Set 3 | athabasca
# Processing Record 44 of Set 3 | meulaboh
# Processing Record 45 of Set 3 | port macquarie
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | alofi
# Processing Record 48 of Set 3 | andijon
# Processing Record 49 of Set 3 | thompson
# Processing Record 50 of Set 3 | solnechnyy
# Processing Record 1 of Set 4 | basco
# Processing Record 2 of Set 4 | toppenish
# Processing Record 3 of Set 4 | topeka
# Processing Record 4 of Set 4 | kununurra
# Processing Record 5 of Set 4 | monatele
# City not found. Skipping...
# Processing Record 6 of Set 4 | vagur
# Processing Record 7 of Set 4 | deputatskiy
# Processing Record 8 of Set 4 | hambantota
# Processing Record 9 of Set 4 | hay river
# Processing Record 10 of Set 4 | curuca
# Processing Record 11 of Set 4 | dongsheng
# Processing Record 12 of Set 4 | mathathane
# Processing Record 13 of Set 4 | madang
# Processing Record 14 of Set 4 | okhotsk
# Processing Record 15 of Set 4 | rawson
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | iqaluit
# Processing Record 18 of Set 4 | husavik
# Processing Record 19 of Set 4 | avarua
# Processing Record 20 of Set 4 | fort nelson
# Processing Record 21 of Set 4 | nemuro
# Processing Record 22 of Set 4 | camacha
# Processing Record 23 of Set 4 | tulcingo
# City not found. Skipping...
# Processing Record 24 of Set 4 | udachnyy
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | guerrero negro
# Processing Record 27 of Set 4 | soyo
# Processing Record 28 of Set 4 | khatanga
# Processing Record 29 of Set 4 | praia
# Processing Record 30 of Set 4 | yebaishou
# Processing Record 31 of Set 4 | banda aceh
# Processing Record 32 of Set 4 | buraydah
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | mattru
# Processing Record 36 of Set 4 | along
# Processing Record 37 of Set 4 | lengshuitan
# Processing Record 38 of Set 4 | yarada
# Processing Record 39 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 4 | maposeni
# Processing Record 41 of Set 4 | vila
# Processing Record 42 of Set 4 | burnie
# Processing Record 43 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 4 | tabas
# Processing Record 45 of Set 4 | rongcheng
# Processing Record 46 of Set 4 | sonoita
# Processing Record 47 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 4 | nhulunbuy
# Processing Record 49 of Set 4 | faya
# Processing Record 50 of Set 4 | komsomolskiy
# Processing Record 1 of Set 5 | laminusa
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | bilibino
# Processing Record 4 of Set 5 | melville
# Processing Record 5 of Set 5 | niesky
# Processing Record 6 of Set 5 | nova paka
# Processing Record 7 of Set 5 | artsvaberd
# Processing Record 8 of Set 5 | brae
# Processing Record 9 of Set 5 | hami
# Processing Record 10 of Set 5 | maryville
# Processing Record 11 of Set 5 | codrington
# Processing Record 12 of Set 5 | flin flon
# Processing Record 13 of Set 5 | cap malheureux
# Processing Record 14 of Set 5 | sao paulo de olivenca
# Processing Record 15 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | barcelos
# Processing Record 17 of Set 5 | kletskaya
# Processing Record 18 of Set 5 | katsuura
# Processing Record 19 of Set 5 | cape town
# Processing Record 20 of Set 5 | tingo maria
# Processing Record 21 of Set 5 | acapulco
# Processing Record 22 of Set 5 | kysyl-syr
# Processing Record 23 of Set 5 | saint-pierre
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | kukes
# Processing Record 26 of Set 5 | nishihara
# Processing Record 27 of Set 5 | marzuq
# Processing Record 28 of Set 5 | pisco
# Processing Record 29 of Set 5 | henties bay
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | zaragoza
# Processing Record 32 of Set 5 | klaksvik
# Processing Record 33 of Set 5 | srandakan
# Processing Record 34 of Set 5 | azrow
# City not found. Skipping...
# Processing Record 35 of Set 5 | mabaruma
# Processing Record 36 of Set 5 | talnakh
# Processing Record 37 of Set 5 | salalah
# Processing Record 38 of Set 5 | kyra
# Processing Record 39 of Set 5 | lons
# Processing Record 40 of Set 5 | ipira
# Processing Record 41 of Set 5 | takoradi
# Processing Record 42 of Set 5 | maymyo
# Processing Record 43 of Set 5 | casablanca
# Processing Record 44 of Set 5 | kahului
# Processing Record 45 of Set 5 | baena
# Processing Record 46 of Set 5 | bredasdorp
# Processing Record 47 of Set 5 | ola
# Processing Record 48 of Set 5 | hofn
# Processing Record 49 of Set 5 | beringovskiy
# Processing Record 50 of Set 5 | boende
# Processing Record 1 of Set 6 | asmar
# Processing Record 2 of Set 6 | margate
# Processing Record 3 of Set 6 | thinadhoo
# Processing Record 4 of Set 6 | darnah
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | huarmey
# Processing Record 7 of Set 6 | marawi
# Processing Record 8 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 9 of Set 6 | semey
# Processing Record 10 of Set 6 | sorland
# Processing Record 11 of Set 6 | popondetta
# Processing Record 12 of Set 6 | gold coast
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | champerico
# Processing Record 15 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 16 of Set 6 | kloulklubed
# Processing Record 17 of Set 6 | san patricio
# Processing Record 18 of Set 6 | himora
# City not found. Skipping...
# Processing Record 19 of Set 6 | sitka
# Processing Record 20 of Set 6 | ust-tarka
# Processing Record 21 of Set 6 | arawa
# Processing Record 22 of Set 6 | jalu
# Processing Record 23 of Set 6 | bermeo
# Processing Record 24 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 6 | pevek
# Processing Record 26 of Set 6 | tanshui
# City not found. Skipping...
# Processing Record 27 of Set 6 | churapcha
# Processing Record 28 of Set 6 | constitucion
# Processing Record 29 of Set 6 | evensk
# Processing Record 30 of Set 6 | lodja
# Processing Record 31 of Set 6 | upington
# Processing Record 32 of Set 6 | flinders
# Processing Record 33 of Set 6 | ribeira grande
# Processing Record 34 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 6 | hervey bay
# Processing Record 36 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 6 | turayf
# Processing Record 38 of Set 6 | alyth
# Processing Record 39 of Set 6 | severo-kurilsk
# Processing Record 40 of Set 6 | andenes
# Processing Record 41 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 6 | tanabe
# Processing Record 43 of Set 6 | turbat
# Processing Record 44 of Set 6 | inhambane
# Processing Record 45 of Set 6 | caarapo
# Processing Record 46 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 6 | east london
# Processing Record 48 of Set 6 | inuvik
# Processing Record 49 of Set 6 | mali
# Processing Record 50 of Set 6 | turukhansk
# Processing Record 1 of Set 7 | puerto maldonado
# Processing Record 2 of Set 7 | fort saint james
# Processing Record 3 of Set 7 | mehamn
# Processing Record 4 of Set 7 | teahupoo
# Processing Record 5 of Set 7 | koch bihar
# Processing Record 6 of Set 7 | onguday
# Processing Record 7 of Set 7 | korla
# Processing Record 8 of Set 7 | konevo
# Processing Record 9 of Set 7 | paamiut
# Processing Record 10 of Set 7 | krasnik
# Processing Record 11 of Set 7 | makueni
# Processing Record 12 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 13 of Set 7 | daru
# Processing Record 14 of Set 7 | shimanovsk
# Processing Record 15 of Set 7 | cabedelo
# Processing Record 16 of Set 7 | wanaka
# Processing Record 17 of Set 7 | dobre miasto
# Processing Record 18 of Set 7 | senno
# Processing Record 19 of Set 7 | alta floresta
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | faanui
# Processing Record 22 of Set 7 | sembakung
# Processing Record 23 of Set 7 | lakatoro
# Processing Record 24 of Set 7 | whitehorse
# Processing Record 25 of Set 7 | sangar
# Processing Record 26 of Set 7 | aden
# Processing Record 27 of Set 7 | vostok
# Processing Record 28 of Set 7 | praia da vitoria
# Processing Record 29 of Set 7 | novoagansk
# Processing Record 30 of Set 7 | yulara
# Processing Record 31 of Set 7 | roura
# Processing Record 32 of Set 7 | funchal
# Processing Record 33 of Set 7 | karlivka
# Processing Record 34 of Set 7 | verdun
# Processing Record 35 of Set 7 | marrakesh
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | zabol
# Processing Record 38 of Set 7 | minot
# Processing Record 39 of Set 7 | thaton
# Processing Record 40 of Set 7 | stephenville crossing
# Processing Record 41 of Set 7 | rafsanjan
# Processing Record 42 of Set 7 | olkhovka
# Processing Record 43 of Set 7 | kahone
# Processing Record 44 of Set 7 | rocha
# Processing Record 45 of Set 7 | saryg-sep
# Processing Record 46 of Set 7 | cidreira
# Processing Record 47 of Set 7 | turan
# Processing Record 48 of Set 7 | vondrozo
# Processing Record 49 of Set 7 | ust-omchug
# Processing Record 50 of Set 7 | buin
# Processing Record 1 of Set 8 | esperance
# Processing Record 2 of Set 8 | dryden
# Processing Record 3 of Set 8 | makat
# Processing Record 4 of Set 8 | maloy
# Processing Record 5 of Set 8 | dickinson
# Processing Record 6 of Set 8 | banfora
# Processing Record 7 of Set 8 | cap-aux-meules
# Processing Record 8 of Set 8 | pouebo
# Processing Record 9 of Set 8 | tasiilaq
# Processing Record 10 of Set 8 | vao
# Processing Record 11 of Set 8 | yekaterinoslavka
# Processing Record 12 of Set 8 | manono
# Processing Record 13 of Set 8 | sao joao da barra
# Processing Record 14 of Set 8 | chapais
# Processing Record 15 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 16 of Set 8 | bijeljina
# Processing Record 17 of Set 8 | rayagada
# Processing Record 18 of Set 8 | junagarh
# Processing Record 19 of Set 8 | rutana
# Processing Record 20 of Set 8 | general roca
# Processing Record 21 of Set 8 | christchurch
# Processing Record 22 of Set 8 | torbay
# Processing Record 23 of Set 8 | kuryk
# Processing Record 24 of Set 8 | olafsvik
# Processing Record 25 of Set 8 | hopewell
# Processing Record 26 of Set 8 | grand-lahou
# Processing Record 27 of Set 8 | maroua
# Processing Record 28 of Set 8 | kwekwe
# Processing Record 29 of Set 8 | sayyan
# Processing Record 30 of Set 8 | ahipara
# Processing Record 31 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 8 | dax
# Processing Record 34 of Set 8 | yeppoon
# Processing Record 35 of Set 8 | dukat
# Processing Record 36 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 8 | kainantu
# Processing Record 38 of Set 8 | gamba
# Processing Record 39 of Set 8 | dakar
# Processing Record 40 of Set 8 | maldonado
# Processing Record 41 of Set 8 | nerchinskiy zavod
# Processing Record 42 of Set 8 | maniitsoq
# Processing Record 43 of Set 8 | tacuarembo
# Processing Record 44 of Set 8 | bandarbeyla
# Processing Record 45 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 8 | hastings
# Processing Record 48 of Set 8 | egvekinot
# Processing Record 49 of Set 8 | littleton
# Processing Record 50 of Set 8 | porto velho
# Processing Record 1 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | maicao
# Processing Record 3 of Set 9 | kodino
# Processing Record 4 of Set 9 | three hills
# Processing Record 5 of Set 9 | tarko-sale
# Processing Record 6 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 9 | salmo
# Processing Record 8 of Set 9 | leshukonskoye
# Processing Record 9 of Set 9 | nanortalik
# Processing Record 10 of Set 9 | chuy
# Processing Record 11 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 9 | cabra
# Processing Record 13 of Set 9 | puerto leguizamo
# Processing Record 14 of Set 9 | comodoro rivadavia
# Processing Record 15 of Set 9 | caceres
# Processing Record 16 of Set 9 | nacala
# Processing Record 17 of Set 9 | pyshchug
# Processing Record 18 of Set 9 | takayama
# Processing Record 19 of Set 9 | lima
# Processing Record 20 of Set 9 | great yarmouth
# Processing Record 21 of Set 9 | idah
# Processing Record 22 of Set 9 | kenai
# Processing Record 23 of Set 9 | mildura
# Processing Record 24 of Set 9 | mecca
# Processing Record 25 of Set 9 | sao filipe
# Processing Record 26 of Set 9 | port lincoln
# Processing Record 27 of Set 9 | sadovoye
# Processing Record 28 of Set 9 | port hedland
# Processing Record 29 of Set 9 | rosarito
# Processing Record 30 of Set 9 | mercedes
# Processing Record 31 of Set 9 | olpad
# Processing Record 32 of Set 9 | ye
# City not found. Skipping...
# Processing Record 33 of Set 9 | eidfjord
# Processing Record 34 of Set 9 | havoysund
# Processing Record 35 of Set 9 | itarema
# Processing Record 36 of Set 9 | abalak
# Processing Record 37 of Set 9 | alenquer
# Processing Record 38 of Set 9 | lebowakgomo
# Processing Record 39 of Set 9 | quelimane
# Processing Record 40 of Set 9 | strezhevoy
# Processing Record 41 of Set 9 | kamenka
# Processing Record 42 of Set 9 | port augusta
# Processing Record 43 of Set 9 | ewa beach
# Processing Record 44 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 9 | tupelo
# Processing Record 46 of Set 9 | vitre
# Processing Record 47 of Set 9 | bilma
# Processing Record 48 of Set 9 | yemelyanovo
# Processing Record 49 of Set 9 | manaquiri
# Processing Record 50 of Set 9 | kushiro
# Processing Record 1 of Set 10 | shimoda
# Processing Record 2 of Set 10 | santa cruz cabralia
# Processing Record 3 of Set 10 | severo-yeniseyskiy
# Processing Record 4 of Set 10 | truth or consequences
# Processing Record 5 of Set 10 | shaunavon
# Processing Record 6 of Set 10 | nanga eboko
# Processing Record 7 of Set 10 | tacuati
# Processing Record 8 of Set 10 | preobrazheniye
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | sanary-sur-mer
# Processing Record 11 of Set 10 | mwinilunga
# Processing Record 12 of Set 10 | guymon
# Processing Record 13 of Set 10 | ercis
# Processing Record 14 of Set 10 | neuquen
# Processing Record 15 of Set 10 | trinidad
# Processing Record 16 of Set 10 | cajati
# Processing Record 17 of Set 10 | bulgan
# Processing Record 18 of Set 10 | samarai
# Processing Record 19 of Set 10 | aklavik
# Processing Record 20 of Set 10 | redlands
# Processing Record 21 of Set 10 | balkhash
# Processing Record 22 of Set 10 | mentor
# Processing Record 23 of Set 10 | selenduma
# Processing Record 24 of Set 10 | berbera
# Processing Record 25 of Set 10 | broken hill
# Processing Record 26 of Set 10 | puerto del rosario
# Processing Record 27 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 10 | chihuahua
# Processing Record 29 of Set 10 | andros town
# Processing Record 30 of Set 10 | zunyi
# Processing Record 31 of Set 10 | uige
# Processing Record 32 of Set 10 | tevaitoa
# Processing Record 33 of Set 10 | ozernovskiy
# Processing Record 34 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 10 | sao gabriel da cachoeira
# Processing Record 36 of Set 10 | plettenberg bay
# Processing Record 37 of Set 10 | sao francisco do sul
# Processing Record 38 of Set 10 | salym
# Processing Record 39 of Set 10 | port hardy
# Processing Record 40 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 10 | iskateley
# Processing Record 42 of Set 10 | manaure
# Processing Record 43 of Set 10 | yola
# Processing Record 44 of Set 10 | fairbanks
# Processing Record 45 of Set 10 | talaja
# Processing Record 46 of Set 10 | kathu
# Processing Record 47 of Set 10 | sisimiut
# Processing Record 48 of Set 10 | marsh harbour
# Processing Record 49 of Set 10 | bowen
# Processing Record 50 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 11 | kaoma
# Processing Record 2 of Set 11 | channel-port aux basques
# Processing Record 3 of Set 11 | craig
# Processing Record 4 of Set 11 | svetlogorsk
# Processing Record 5 of Set 11 | porto novo
# Processing Record 6 of Set 11 | la palma
# Processing Record 7 of Set 11 | domna
# Processing Record 8 of Set 11 | milkovo
# Processing Record 9 of Set 11 | palmer
# Processing Record 10 of Set 11 | sabang
# Processing Record 11 of Set 11 | marakkanam
# Processing Record 12 of Set 11 | oudtshoorn
# Processing Record 13 of Set 11 | marti
# Processing Record 14 of Set 11 | tocopilla
# Processing Record 15 of Set 11 | vila franca do campo
# Processing Record 16 of Set 11 | aswan
# Processing Record 17 of Set 11 | hualmay
# Processing Record 18 of Set 11 | tuatapere
# Processing Record 19 of Set 11 | rorvik
# Processing Record 20 of Set 11 | nantucket
# Processing Record 21 of Set 11 | nchelenge
# Processing Record 22 of Set 11 | seoul
# Processing Record 23 of Set 11 | taoudenni
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | bonavista
# Processing Record 26 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 11 | mount pleasant
# Processing Record 28 of Set 11 | kahramanmaras
# Processing Record 29 of Set 11 | padang
# Processing Record 30 of Set 11 | qena
# Processing Record 31 of Set 11 | alice springs
# Processing Record 32 of Set 11 | alugan
# Processing Record 33 of Set 11 | bairiki
# Processing Record 34 of Set 11 | iquitos
# Processing Record 35 of Set 11 | amapa
# Processing Record 36 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 11 | petauke
# Processing Record 39 of Set 11 | amot
# Processing Record 40 of Set 11 | matamoros
# Processing Record 41 of Set 11 | kavieng
# Processing Record 42 of Set 11 | zonguldak
# Processing Record 43 of Set 11 | tucuman
# Processing Record 44 of Set 11 | antalaha
# Processing Record 45 of Set 11 | maceio
# Processing Record 46 of Set 11 | lerwick
# Processing Record 47 of Set 11 | san cristobal
# Processing Record 48 of Set 11 | barra do garcas
# Processing Record 49 of Set 11 | koslan
# Processing Record 50 of Set 11 | imeni zhelyabova
# Processing Record 1 of Set 12 | sala
# Processing Record 2 of Set 12 | ban nahin
# Processing Record 3 of Set 12 | torbat-e jam
# Processing Record 4 of Set 12 | yumen
# Processing Record 5 of Set 12 | petrykiv
# Processing Record 6 of Set 12 | tyukhtet
# Processing Record 7 of Set 12 | raahe
# Processing Record 8 of Set 12 | dudinka
# Processing Record 9 of Set 12 | clifton
# Processing Record 10 of Set 12 | berdigestyakh
# Processing Record 11 of Set 12 | malumfashi
# Processing Record 12 of Set 12 | los llanos de aridane
# Processing Record 13 of Set 12 | north platte
# Processing Record 14 of Set 12 | asau
# Processing Record 15 of Set 12 | kesova gora
# Processing Record 16 of Set 12 | coihaique
# Processing Record 17 of Set 12 | naples
# Processing Record 18 of Set 12 | ixtapa
# Processing Record 19 of Set 12 | temir
# Processing Record 20 of Set 12 | port-gentil
# Processing Record 21 of Set 12 | prince rupert
# Processing Record 22 of Set 12 | tecpan
# Processing Record 23 of Set 12 | tautira
# Processing Record 24 of Set 12 | lavrentiya
# Processing Record 25 of Set 12 | taltal
# Processing Record 26 of Set 12 | sakaiminato
# Processing Record 27 of Set 12 | san rafael
# Processing Record 28 of Set 12 | indramayu
# Processing Record 29 of Set 12 | berlevag
# Processing Record 30 of Set 12 | san jose
# Processing Record 31 of Set 12 | avera
# Processing Record 32 of Set 12 | marstal
# Processing Record 33 of Set 12 | oum hadjer
# Processing Record 34 of Set 12 | duku
# Processing Record 35 of Set 12 | bargteheide
# Processing Record 36 of Set 12 | santiago do cacem
# Processing Record 37 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 38 of Set 12 | bom jesus
# Processing Record 39 of Set 12 | silopi
# Processing Record 40 of Set 12 | rizhao
# Processing Record 41 of Set 12 | ptuj
# Processing Record 42 of Set 12 | port-cartier
# Processing Record 43 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 44 of Set 12 | roald
# Processing Record 45 of Set 12 | horta
# Processing Record 46 of Set 12 | cervo
# Processing Record 47 of Set 12 | aktas
# Processing Record 48 of Set 12 | namibe
# Processing Record 49 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 12 | broome
# Processing Record 1 of Set 13 | goicea
# Processing Record 2 of Set 13 | kiama
# Processing Record 3 of Set 13 | saint-joseph
# Processing Record 4 of Set 13 | marienburg
# Processing Record 5 of Set 13 | alekseyevsk
# Processing Record 6 of Set 13 | colon
# Processing Record 7 of Set 13 | sao jose da tapera
# Processing Record 8 of Set 13 | atbasar
# Processing Record 9 of Set 13 | serebryansk
# Processing Record 10 of Set 13 | russell
# Processing Record 11 of Set 13 | sioux lookout
# Processing Record 12 of Set 13 | aranos
# Processing Record 13 of Set 13 | matanzas
# Processing Record 14 of Set 13 | mareeba
# Processing Record 15 of Set 13 | sept-iles
# Processing Record 16 of Set 13 | batagay
# Processing Record 17 of Set 13 | tapiramuta
# Processing Record 18 of Set 13 | makakilo city
# Processing Record 19 of Set 13 | ust-kan
# Processing Record 20 of Set 13 | mount isa
# Processing Record 21 of Set 13 | la ronge
# Processing Record 22 of Set 13 | abramovka
# Processing Record 23 of Set 13 | limon
# Processing Record 24 of Set 13 | varfurile
# Processing Record 25 of Set 13 | ustye
# Processing Record 26 of Set 13 | pitimbu
# Processing Record 27 of Set 13 | ila
# Processing Record 28 of Set 13 | chateau-gontier
# Processing Record 29 of Set 13 | ambon
# Processing Record 30 of Set 13 | calvinia
# Processing Record 31 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 13 | arrifes
# Processing Record 33 of Set 13 | maningrida
# Processing Record 34 of Set 13 | cayenne
# Processing Record 35 of Set 13 | winnemucca
# Processing Record 36 of Set 13 | adjumani
# Processing Record 37 of Set 13 | marsaxlokk
# Processing Record 38 of Set 13 | college
# Processing Record 39 of Set 13 | totness
# Processing Record 40 of Set 13 | sredniy ikorets
# Processing Record 41 of Set 13 | buala
# Processing Record 42 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 13 | mumford
# Processing Record 44 of Set 13 | trairi
# Processing Record 45 of Set 13 | eagle pass
# Processing Record 46 of Set 13 | vardo
# Processing Record 47 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 13 | mamlyutka
# Processing Record 49 of Set 13 | fukue
# Processing Record 50 of Set 13 | zemetchino
# Processing Record 1 of Set 14 | restrepo
# Processing Record 2 of Set 14 | maputo
# Processing Record 3 of Set 14 | matay
# Processing Record 4 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 14 | tigzirt
# Processing Record 6 of Set 14 | shelton
# Processing Record 7 of Set 14 | esmeraldas
# Processing Record 8 of Set 14 | halifax
# Processing Record 9 of Set 14 | maraa
# Processing Record 10 of Set 14 | tevriz
# Processing Record 11 of Set 14 | san ramon
# Processing Record 12 of Set 14 | shilka
# Processing Record 13 of Set 14 | selenginsk
# Processing Record 14 of Set 14 | denpasar
# Processing Record 15 of Set 14 | eureka
# Processing Record 16 of Set 14 | tilichiki
# Processing Record 17 of Set 14 | yichang
# Processing Record 18 of Set 14 | neyshabur
# Processing Record 19 of Set 14 | matiguas
# Processing Record 20 of Set 14 | southbridge
# Processing Record 21 of Set 14 | bunog
# Processing Record 22 of Set 14 | ardatov
# Processing Record 23 of Set 14 | teguldet
# Processing Record 24 of Set 14 | ust-ilimsk
# Processing Record 25 of Set 14 | loandjili
# Processing Record 26 of Set 14 | svetlaya
# Processing Record 27 of Set 14 | aksay
# Processing Record 28 of Set 14 | santa rosa
# Processing Record 29 of Set 14 | oga
# Processing Record 30 of Set 14 | ostrovnoy
# Processing Record 31 of Set 14 | saint augustine
# Processing Record 32 of Set 14 | half moon bay
# Processing Record 33 of Set 14 | tura
# Processing Record 34 of Set 14 | fuerte olimpo
# Processing Record 35 of Set 14 | yamada
# Processing Record 36 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 14 | chulym
# Processing Record 38 of Set 14 | erenhot
# Processing Record 39 of Set 14 | ust-kuyga
# Processing Record 40 of Set 14 | concepcion del uruguay
# Processing Record 41 of Set 14 | krasnoselkup
# Processing Record 42 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 43 of Set 14 | sturgis
# Processing Record 44 of Set 14 | kaeo
# Processing Record 45 of Set 14 | roswell
# Processing Record 46 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 47 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 14 | bagotville
# Processing Record 49 of Set 14 | valparaiso
# Processing Record 50 of Set 14 | changli
# Processing Record 1 of Set 15 | den helder
# Processing Record 2 of Set 15 | bezhetsk
# Processing Record 3 of Set 15 | skelleftea
# Processing Record 4 of Set 15 | sorong
# Processing Record 5 of Set 15 | heihe
# Processing Record 6 of Set 15 | cockburn town
# Processing Record 7 of Set 15 | tokzar
# City not found. Skipping...
# Processing Record 8 of Set 15 | dunedin
# Processing Record 9 of Set 15 | huilong
# Processing Record 10 of Set 15 | tekari
# Processing Record 11 of Set 15 | chamba
# Processing Record 12 of Set 15 | palasa
# Processing Record 13 of Set 15 | ofaqim
# Processing Record 14 of Set 15 | lircay
# Processing Record 15 of Set 15 | zhanaozen
# Processing Record 16 of Set 15 | batemans bay
# Processing Record 17 of Set 15 | villarrica
# Processing Record 18 of Set 15 | omboue
# Processing Record 19 of Set 15 | port keats
# Processing Record 20 of Set 15 | kieta
# Processing Record 21 of Set 15 | launceston
# Processing Record 22 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 15 | taywarah
# Processing Record 24 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 25 of Set 15 | reyes
# Processing Record 26 of Set 15 | morehead
# Processing Record 27 of Set 15 | puerto escondido
# Processing Record 28 of Set 15 | mookane
# Processing Record 29 of Set 15 | havelock
# Processing Record 30 of Set 15 | santa marta
# Processing Record 31 of Set 15 | belmonte
# Processing Record 32 of Set 15 | hudiksvall
# Processing Record 33 of Set 15 | tromso
# Processing Record 34 of Set 15 | port hawkesbury
# Processing Record 35 of Set 15 | hamilton
# Processing Record 36 of Set 15 | jumla
# Processing Record 37 of Set 15 | bantou
# Processing Record 38 of Set 15 | honiara
# Processing Record 39 of Set 15 | viedma
# Processing Record 40 of Set 15 | innisfail
# Processing Record 41 of Set 15 | angren
# Processing Record 42 of Set 15 | ketchikan
# Processing Record 43 of Set 15 | naze
# Processing Record 44 of Set 15 | grindavik
# Processing Record 45 of Set 15 | caxito
# Processing Record 46 of Set 15 | nurota
# Processing Record 47 of Set 15 | les cayes
# Processing Record 48 of Set 15 | charters towers
# Processing Record 49 of Set 15 | kerava
# Processing Record 50 of Set 15 | njombe
# Processing Record 1 of Set 16 | edmundston
# Processing Record 2 of Set 16 | panaba
# Processing Record 3 of Set 16 | sayula
# Processing Record 4 of Set 16 | saint anthony
# Processing Record 5 of Set 16 | tapah
# Processing Record 6 of Set 16 | yablochnyy
# Processing Record 7 of Set 16 | grafton
# Processing Record 8 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 16 | imbituba
# Processing Record 10 of Set 16 | the valley
# Processing Record 11 of Set 16 | ipanema
# Processing Record 12 of Set 16 | derbent
# Processing Record 13 of Set 16 | seguin
# Processing Record 14 of Set 16 | akyab
# Processing Record 15 of Set 16 | manhush
# Processing Record 16 of Set 16 | artvin
# Processing Record 17 of Set 16 | mitsamiouli
# Processing Record 18 of Set 16 | bull savanna
# Processing Record 19 of Set 16 | havre-saint-pierre
# Processing Record 20 of Set 16 | samsun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Mataura      NZ -46.1927  168.8643     33.06        90
# 1              Xining      CN  36.6167  101.7667     56.23        86
# 2         Clyde River      CA  70.4692  -68.5914     39.43        87
# 3           Busselton      AU -33.6500  115.3333     53.49        66
# 4  San Rafael Del Sur      NI  11.8485  -86.4384     83.37        80
#
#    Cloudiness  Wind Speed Current Description
# 0         100        2.77     overcast clouds
# 1         100        2.73     overcast clouds
# 2          75        9.22       broken clouds
# 3          94        8.37     overcast clouds
# 4         100        7.31     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
